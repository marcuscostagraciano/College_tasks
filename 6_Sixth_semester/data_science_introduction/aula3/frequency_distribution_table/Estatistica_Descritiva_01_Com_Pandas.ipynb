# %% [markdown]
# # ***Estatistica Descritiva com Pandas***

# %% [markdown]
# # **Carregando os dados**

# %%
import numpy as np
import pandas as pd

# %%
dfPoll = pd.read_csv('dataset.csv')

# %%
# lista os 5 primeiros registros do dataset
dfPoll.head()
# Out:
#    Qual sua idade?   Qual sua altura em metros?  Seu peso em kg. Sexo?  \
# 0                20                        1.82               85     M
# 1                25                        1.72               64     M
# 2                29                        1.82               65     M
# 3                27                        1.63               60     F
# 4                28                        1.57               63     F
#
#                       Grau de escolaridade? Em qual estado você nasceu?  \
# 0  Ensino superior (completo ou incompleto)                          SP
# 1    Pós-graduação (completo ou incompleto)                          MS
# 2    Pós-graduação (completo ou incompleto)                          SP
# 3    Pós-graduação (completo ou incompleto)                          MS
# 4  Ensino superior (completo ou incompleto)                          MS
#
#    Em quantos irmãos vocês são (contando contigo)?  \
# 0                                                3
# 1                                                5
# 2                                                1
# 3                                                2
# 4                                                2
#
#    Quantos membros tem sua família? (Quantos moram contigo, ou 1 caso more sozinho)  \
# 0                                                  5
# 1                                                  1
# 2                                                  2
# 3                                                  4
# 4                                                  3
#
#   Você trabalha/estuda atualmente? Qual atividade realiza com mais frequência?
# 0                trabalho e estudo                                    Cozinhar
# 1                           estudo                                 Rede social
# 2                           estudo                                   Ler livro
# 3                         trabalho                                 Assistir TV
# 4                           estudo                                 Rede social

# %%
# observar o tamanho do dataset (dataframe)
# lista o número de linhas e o número de colunas
dfPoll.shape

# %%
# alterar o nome das colunas do dataset
dfPoll.columns =['idade', 'altura_m', 'peso_kg', 'sexo', 'escolaridade', 'estado', 'qtde_irmaos_maisvoce', 'numero_familiares', 'trabalha_estuda', 'atividade_frequente']

# %%
# lista os 5 primeiros registros do dataset novamente
dfPoll.head()
# Out:
#    idade  altura_m  peso_kg sexo                              escolaridade  \
# 0     20      1.82       85    M  Ensino superior (completo ou incompleto)
# 1     25      1.72       64    M    Pós-graduação (completo ou incompleto)
# 2     29      1.82       65    M    Pós-graduação (completo ou incompleto)
# 3     27      1.63       60    F    Pós-graduação (completo ou incompleto)
# 4     28      1.57       63    F  Ensino superior (completo ou incompleto)
#
#   estado  qtde_irmaos_maisvoce  numero_familiares    trabalha_estuda  \
# 0     SP                     3                  5  trabalho e estudo
# 1     MS                     5                  1             estudo
# 2     SP                     1                  2             estudo
# 3     MS                     2                  4           trabalho
# 4     MS                     2                  3             estudo
#
#   atividade_frequente
# 0            Cozinhar
# 1         Rede social
# 2           Ler livro
# 3         Assistir TV
# 4         Rede social

# %% [markdown]
# # **Tabela de Distribuição de Frequências com Pandas**

# %% [markdown]
# **Calculando a Frequência Absoluta**

# %%
#Contamos a frequência para cada valor da columa 'freq_activity'
dfPoll['atividade_frequente'].value_counts()
# Out:
# Rede social         20
# Ler livro           15
# Assistir TV         12
# Jogar videogame     12
# Cozinhar             6
# Praticar esporte     3
# Name: atividade_frequente, dtype: int64

# %%
#Para somar o total da coluna
sum(dfPoll['atividade_frequente'].value_counts())
# Out:
# 68

# %%
# outra maneira de somar o total da coluna
dfPoll['atividade_frequente'].value_counts().sum()
# Out:
# 68

# %% [markdown]
# **Calculando a Frequência Relativa**

# %%
#É a proporção da frequência absoluta comparada com o total dos dados. A soma das frequências relativas deve ser 1
#A mesma ideia de contar o número de vezes que um valor aparece, mas em relação a todos os dados
df = dfPoll['atividade_frequente'].value_counts()
df / len(dfPoll['atividade_frequente'])
# Out:
# Rede social         0.294118
# Ler livro           0.220588
# Assistir TV         0.176471
# Jogar videogame     0.176471
# Cozinhar            0.088235
# Praticar esporte    0.044118
# Name: atividade_frequente, dtype: float64

# %% [markdown]
# **Calculando a Frequência Acumulada**

# %%
#A frequência acumulada depende de todos os valores porque devemos soma-los até que tenhamos os dados 𝑁.
#Funciona para frequências absolutas e relativas.
#Portanto, na primeira linha teríamos 𝑓1, na segunda linha 𝑓1 + 𝑓2 e assim por diante.
dfPoll['atividade_frequente'].value_counts().cumsum()
# Out:
# Rede social         20
# Ler livro           35
# Assistir TV         47
# Jogar videogame     59
# Cozinhar            65
# Praticar esporte    68
# Name: atividade_frequente, dtype: int64

# %% [markdown]
# **Exemplo de Uma Tabela de Distribuição de Frequências**

# %%
#Exemplo de uma tabela completa para a variável 'freq_activity'
dfFrequencies = dfPoll['atividade_frequente'].value_counts().to_frame()

dfFrequencies['relativa'] = dfPoll['atividade_frequente'].value_counts()/len(dfPoll['atividade_frequente'])

dfFrequencies['acumulada'] = dfPoll['atividade_frequente'].value_counts().cumsum()

dfFrequencies['relacum'] = (dfPoll['atividade_frequente'].value_counts()/len(dfPoll['atividade_frequente'])).cumsum()

dfFrequencies = dfFrequencies.reset_index()

row = {'index':'Totais (∑)', 'atividade_frequente': sum(dfFrequencies['atividade_frequente']), 'relativa': sum(dfFrequencies['relativa'])}

dfFrequencies = dfFrequencies.append(row, ignore_index = True)

dfFrequencies.columns = ['Atividade', 'Frequência Absoluta Simples', 'Frequência Relativa Simples', 'Frequência Absoluta Acumulada', 'Frequência Relativa Acumulada']

dfFrequencies = dfFrequencies.fillna('-')

dfFrequencies
# Out:
#           Atividade  Frequência Absoluta Simples  Frequência Relativa Simples  \
# 0       Rede social                           20                     0.294118
# 1         Ler livro                           15                     0.220588
# 2       Assistir TV                           12                     0.176471
# 3   Jogar videogame                           12                     0.176471
# 4          Cozinhar                            6                     0.088235
# 5  Praticar esporte                            3                     0.044118
# 6        Totais (∑)                           68                     1.000000
#
#   Frequência Absoluta Acumulada Frequência Relativa Acumulada
# 0                          20.0                      0.294118
# 1                          35.0                      0.514706
# 2                          47.0                      0.691176
# 3                          59.0                      0.867647
# 4                          65.0                      0.955882
# 5                          68.0                           1.0
# 6                             -                             -

# %%
#Exemplo de uma tabela completa para a variável 'state'
dfFrequencies = dfPoll['state'].value_counts().to_frame()

dfFrequencies['relative'] = dfPoll['state'].value_counts()/len(dfPoll['state'])

dfFrequencies['cumulative'] = dfPoll['state'].value_counts().cumsum()

dfFrequencies['relcum'] = (dfPoll['state'].value_counts()/len(dfPoll['state'])).cumsum()

dfFrequencies = dfFrequencies.reset_index()

row = {'index':'Totais (∑)', 'state': sum(dfFrequencies['state']), 'relative': sum(dfFrequencies['relative'])}

dfFrequencies = dfFrequencies.append(row, ignore_index = True)

dfFrequencies.columns = ['State', 'Simple absolute frequency', 'Simple relative frequency', 'Cumulative absolute frequency', 'Cumulative relative frequency']

dfFrequencies = dfFrequencies.fillna('-')

dfFrequencies
# Out:
#          State  Simple absolute frequency  Simple relative frequency  \
# 0           SP                         45                   0.661765
# 1           MS                          9                   0.132353
# 2           MG                          6                   0.088235
# 3           GO                          2                   0.029412
# 4           RJ                          2                   0.029412
# 5           RO                          1                   0.014706
# 6           PI                          1                   0.014706
# 7           PR                          1                   0.014706
# 8  Estrangeiro                          1                   0.014706
# 9   Totais (∑)                         68                   1.000000
#
#   Cumulative absolute frequency Cumulative relative frequency
# 0                          45.0                      0.661765
# 1                          54.0                      0.794118
# 2                          60.0                      0.882353
# 3                          62.0                      0.911765
# 4                          64.0                      0.941176
# 5                          65.0                      0.955882
# 6                          66.0                      0.970588
# 7                          67.0                      0.985294
# 8                          68.0                           1.0
# 9                             -                             -

# %% [markdown]
# # **Desafio**

# %% [markdown]
# **Escolha uma das colunas do "dataset.csv" e crie a tabela de distribuição de frequência usando o Pandas**
